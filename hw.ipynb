# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (18, 10)
countries=nx.Graph()
countries.add_edge('Armenia', 'Georgia')
countries.add_edge('Armenia', 'Turkey')
countries.add_edge('Albania', 'Greece') 
countries.add_edge('Albania', 'Kosovo')
countries.add_edge('Albania', 'North Macedonia')
countries.add_edge('Albania', 'Montenegro')
countries.add_edge('Andorra', 'France')
countries.add_edge('Andorra', 'Spain')
countries.add_edge('Austria', 'Czech Republic')
countries.add_edge('Austria', 'Germany')
countries.add_edge('Austria', 'Hungary')
countries.add_edge('Austria', 'Italy')
countries.add_edge('Austria', 'Liechtenstein')
countries.add_edge('Austria', 'Slovakia')
countries.add_edge('Austria', 'Slovenia')
countries.add_edge('Austria', 'Switzerland')
countries.add_edge('Belarus', 'Latvia')
countries.add_edge('Belarus', 'Lithuania')
countries.add_edge('Belarus', 'Poland')
countries.add_edge('Belarus', 'Russia')
countries.add_edge('Belarus', 'Ukraine')
countries.add_edge('Belgium', 'France')
countries.add_edge('Belgium', 'Germany')
countries.add_edge('Belgium', 'Luxembourg')
countries.add_edge('Belgium', 'Netherlands')
countries.add_edge('Bosnia and Herzegovina', 'Croatia')
countries.add_edge('Bosnia and Herzegovina', 'Montenegro')
countries.add_edge('Bosnia and Herzegovina', 'Serbia')
countries.add_edge('Bulgaria', 'Greece')
countries.add_edge('Bulgaria', 'North Macedonia')
countries.add_edge('Bulgaria', 'Romania')
countries.add_edge('Bulgaria', 'Serbia')
countries.add_edge('Bulgaria', 'Turkey')
countries.add_edge('Croatia', 'Hungary')
countries.add_edge('Croatia', 'Montenegro')
countries.add_edge('Croatia', 'Serbia')
countries.add_edge('Croatia', 'Slovenia')
countries.add_edge('Czech Republic', 'Germany')
countries.add_edge('Czech Republic', 'Poland')
countries.add_edge('Czech Republic', 'Slovakia')
countries.add_edge('Denmark', 'Germany')
countries.add_edge('Estonia', 'Latvia')
countries.add_edge('Estonia', 'Russia')
countries.add_edge('Finland', 'Norway')
countries.add_edge('Finland', 'Sweden')
countries.add_edge('Finland', 'Russia')
countries.add_edge('France', 'Germany')
countries.add_edge('France', 'Italy')
countries.add_edge('France', 'Luxembourg')
countries.add_edge('France', 'Monaco')
countries.add_edge('France', 'Spain')
countries.add_edge('France', 'Switzerland')
countries.add_edge('Germany', 'Luxembourg')
countries.add_edge('Germany', 'Netherlands')
countries.add_edge('Germany', 'Poland')
countries.add_edge('Germany', 'Switzerland')
countries.add_edge('Georgia', 'Russia')
countries.add_edge('Georgia', 'Turkey')
countries.add_edge('Greece', 'Turkey')
countries.add_edge('Greece', 'North Macedonia')
countries.add_edge('Hungary', 'Romania')
countries.add_edge('Hungary', 'Serbia')
countries.add_edge('Hungary', 'Slovakia')
countries.add_edge('Hungary', 'Slovenia')
countries.add_edge('Hungary', 'Ukraine')
countries.add_edge('Ireland', 'United Kingdom')
countries.add_edge('Italy', 'San Marino')
countries.add_edge('Italy', 'Slovenia')
countries.add_edge('Italy', 'Switzerland')
countries.add_edge('Italy', 'Vatican City')
countries.add_edge('Kosovo', 'Montenegro')
countries.add_edge('Kosovo', 'North Macedonia')
countries.add_edge('Kosovo', 'Serbia')
countries.add_edge('Latvia', 'Lithuania')
countries.add_edge('Latvia', 'Russia')
countries.add_edge('Liechtenstein', 'Switzerland')
countries.add_edge('Lithuania', 'Poland')
countries.add_edge('Lithuania', 'Russia')
countries.add_edge('Moldova', 'Romania')
countries.add_edge('Moldova', 'Ukraine')
countries.add_edge('Montenegro', 'Serbia')
countries.add_edge('North Macedonia', 'Serbia')
countries.add_edge('Norway', 'Sweden')
countries.add_edge('Norway', 'Russia')
countries.add_edge('Poland', 'Russia')
countries.add_edge('Poland', 'Slovakia')
countries.add_edge('Poland', 'Ukraine')
countries.add_edge('Portugal', 'Spain')
countries.add_edge('Romania', 'Serbia')
countries.add_edge('Romania', 'Ukraine')
countries.add_edge('Russia', 'Ukraine')
countries.add_edge('Slovakia', 'Ukraine') 
countries.add_node('Cyprus')
countries.add_node('Iceland')
countries.add_node('Malta')

nx.draw_planar(countries, with_labels=True)

# %%
print("number of vertices =", countries.number_of_nodes())
print("number of edges =", countries.number_of_edges())
#Так как у нас есть висячие вершины, то минимальная степень будет равна 1.
#Максимальная степень будет равна 9, что нетрудно заметить из списка ребер
print("min deg(v) = 0")
print("max deg(v) = 9")
graph=countries.subgraph(max(nx.connected_components(countries)))
nx.draw_planar(graph, with_labels=True)
print("rad =", nx.radius(graph))
print("diam =", nx.diameter(graph)) 
print("girth =", min([len(cycle) for cycle in nx.cycle_basis(graph)]))
print("center =", nx.center(graph))
#Нетрудно заметить, что при удалении вершины "Italy" граф становится несвязным, так как данная вершина связана с двумя 
#изолированными, а значит минимальное число ребер(и вершин), которое надо удалить, чтобы граф стал несвязным равно 1.
print("x(g) = 1")
print("l(g) = 1")
# Out:
# number of vertices = 49
# number of edges = 92
# min deg(v) = 0
# max deg(v) = 9
# rad = 5
# diam = 8
# girth = 3
# center = ['Austria', 'Czech Republic', 'Germany', 'Hungary', 'Slovakia', 'Slovenia', 'Switzerland', 'Belarus', 'Lithuania', 'Poland', 'Russia', 'Ukraine', 'Croatia']
# x(g) = 1
# l(g) = 1

# %%
print(nx.greedy_color(graph))
print("Из полученной раскраски нетрудно заметить, что:")
print("Minimum vertex coloring = 5")
# Out:
# {'Germany': 0, 'Russia': 0, 'France': 1, 'Austria': 1, 'Serbia': 0, 'Hungary': 2, 'Poland': 1, 'Ukraine': 3, 'Italy': 0, 'North Macedonia': 1, 'Montenegro': 1, 'Slovakia': 0, 'Switzerland': 2, 'Belarus': 2, 'Croatia': 3, 'Bulgaria': 2, 'Romania': 1, 'Turkey': 0, 'Albania': 0, 'Greece': 3, 'Kosovo': 2, 'Czech Republic': 2, 'Slovenia': 4, 'Latvia': 1, 'Lithuania': 3, 'Belgium': 2, 'Georgia': 1, 'Spain': 0, 'Luxembourg': 3, 'Bosnia and Herzegovina': 2, 'Finland': 1, 'Norway': 2, 'Armenia': 2, 'Andorra': 2, 'Liechtenstein': 0, 'Netherlands': 1, 'Estonia': 2, 'Sweden': 0, 'Moldova': 0, 'Denmark': 1, 'Monaco': 0, 'San Marino': 1, 'Vatican City': 1, 'Portugal': 1}
# Из полученной раскраски нетрудно заметить, что:
# Minimum vertex coloring = 4

# %%
temp=nx.line_graph(graph)
print(nx.greedy_color(temp))
print("Из полученной раскраски нетрудно заметить, что:")
print("Minimum edge coloring = 9")
# Out:
# {('Austria', 'Germany'): 0, ('France', 'Germany'): 1, ('Germany', 'Poland'): 2, ('Russia', 'Ukraine'): 0, ('Poland', 'Russia'): 1, ('Austria', 'Hungary'): 1, ('Hungary', 'Serbia'): 0, ('Poland', 'Ukraine'): 3, ('Hungary', 'Ukraine'): 2, ('Germany', 'Switzerland'): 3, ('Belarus', 'Russia'): 2, ('France', 'Italy'): 0, ('Austria', 'Italy'): 2, ('Montenegro', 'Serbia'): 1, ('North Macedonia', 'Serbia'): 2, ('Romania', 'Serbia'): 3, ('Bulgaria', 'Serbia'): 4, ('Lithuania', 'Russia'): 3, ('Czech Republic', 'Germany'): 4, ('Latvia', 'Russia'): 4, ('Austria', 'Switzerland'): 4, ('Austria', 'Slovakia'): 3, ('France', 'Switzerland'): 2, ('Belgium', 'Germany'): 5, ('Croatia', 'Serbia'): 5, ('Norway', 'Russia'): 5, ('Belarus', 'Ukraine'): 1, ('Belarus', 'Poland'): 0, ('Poland', 'Slovakia'): 4, ('Germany', 'Luxembourg'): 6, ('Romania', 'Ukraine'): 4, ('Slovakia', 'Ukraine'): 5, ('Georgia', 'Russia'): 6, ('Finland', 'Russia'): 7, ('Belgium', 'France'): 3, ('Kosovo', 'Serbia'): 6, ('Hungary', 'Slov
# ...

# %%
print("Maximum clique:", nx.approximation.max_clique(graph))
# Out:
# Maximum clique: {'Ukraine', 'Russia', 'Belarus', 'Poland'}

# %%
print("Maximum stable set:", nx.maximal_independent_set(graph))
# Out:
# Maximum stable set: ['Hungary', 'Turkey', 'Belgium', 'Monaco', 'Andorra', 'Norway', 'Italy', 'Lithuania', 'Albania', 'Czech Republic', 'Bosnia and Herzegovina', 'Liechtenstein', 'Moldova', 'Estonia', 'Portugal', 'Denmark']

# %%
print("Maximum matching:", nx.max_weight_matching(graph))
# Out:
# Maximum matching: {('Moldova', 'Romania'), ('Bulgaria', 'Greece'), ('Portugal', 'Spain'), ('Kosovo', 'Serbia'), ('Armenia', 'Turkey'), ('Russia', 'Norway'), ('Germany', 'Denmark'), ('Croatia', 'Slovenia'), ('Montenegro', 'Bosnia and Herzegovina'), ('North Macedonia', 'Albania'), ('Monaco', 'France'), ('Ukraine', 'Belarus'), ('Sweden', 'Finland'), ('Lithuania', 'Poland'), ('Netherlands', 'Belgium'), ('Switzerland', 'Liechtenstein'), ('Slovakia', 'Hungary'), ('Vatican City', 'Italy'), ('Estonia', 'Latvia'), ('Austria', 'Czech Republic')}

# %%
print("Minimum vertex cover:", nx.approximation.min_weighted_vertex_cover(graph))
# Out:
# Minimum vertex cover: {'Finland', 'Russia', 'Latvia', 'Montenegro', 'Austria', 'Armenia', 'Bulgaria', 'Albania', 'Liechtenstein', 'Hungary', 'Croatia', 'North Macedonia', 'Greece', 'Andorra', 'Slovakia', 'Kosovo', 'France', 'Georgia', 'Lithuania', 'Moldova', 'Turkey', 'Portugal', 'Serbia', 'Switzerland', 'Poland', 'San Marino', 'Germany', 'Ukraine', 'Czech Republic', 'Belarus', 'Belgium', 'Norway', 'Spain', 'Italy'}

# %%
print("Minimum edge cover:", nx.min_edge_cover(graph))
# Out:
# Minimum edge cover: {('Moldova', 'Romania'), ('France', 'Andorra'), ('Bulgaria', 'Greece'), ('Belgium', 'Luxembourg'), ('Armenia', 'Georgia'), ('Portugal', 'Spain'), ('Kosovo', 'Serbia'), ('Armenia', 'Turkey'), ('Russia', 'Norway'), ('Germany', 'Denmark'), ('San Marino', 'Italy'), ('Croatia', 'Slovenia'), ('Montenegro', 'Bosnia and Herzegovina'), ('Italy', 'San Marino'), ('North Macedonia', 'Albania'), ('Monaco', 'France'), ('Georgia', 'Armenia'), ('Ukraine', 'Belarus'), ('Sweden', 'Finland'), ('Andorra', 'France'), ('Luxembourg', 'Belgium'), ('Lithuania', 'Poland'), ('Netherlands', 'Belgium'), ('Switzerland', 'Liechtenstein'), ('Slovakia', 'Hungary'), ('Vatican City', 'Italy'), ('Estonia', 'Latvia'), ('Austria', 'Czech Republic')}

# %%
print("Shortest closed walk that visits every vertex:")
print(nx.approximation.traveling_salesman_problem(graph))
# Out:
# Shortest closed walk that visits every vertex:
# ['Armenia', 'Turkey', 'Bulgaria', 'Greece', 'Albania', 'North Macedonia', 'Serbia', 'Kosovo', 'Montenegro', 'Bosnia and Herzegovina', 'Croatia', 'Hungary', 'Romania', 'Moldova', 'Ukraine', 'Hungary', 'Austria', 'Slovenia', 'Austria', 'Slovakia', 'Austria', 'Liechtenstein', 'Switzerland', 'France', 'Monaco', 'France', 'Luxembourg', 'Germany', 'Denmark', 'Germany', 'Netherlands', 'Belgium', 'France', 'Italy', 'Vatican City', 'Italy', 'San Marino', 'Italy', 'France', 'Spain', 'Portugal', 'Spain', 'Andorra', 'France', 'Germany', 'Czech Republic', 'Poland', 'Belarus', 'Lithuania', 'Latvia', 'Estonia', 'Russia', 'Norway', 'Sweden', 'Finland', 'Russia', 'Georgia', 'Armenia']

# %%
print("Shortest closed walk that visits every edge:")
print(nx.approximation.traveling_salesman_problem(nx.line_graph(graph)))
# Out:
# Shortest closed walk that visits every edge:
# ...

# %%
print("All biconnected components:", list(nx.biconnected_components(graph)))
print("The block-cut tree:")
cut_tree = nx.Graph()
cut_tree.add_edge('PS', 'SFA')
cut_tree.add_edge('SFA', 'MF')
cut_tree.add_edge('SFA', 'NRRELect')
cut_tree.add_edge('SFA', 'SI')
cut_tree.add_edge('SFA', 'VI')
cut_tree.add_edge('SI', 'VI')
cut_tree.add_edge('SI', 'NRRELect')
cut_tree.add_edge('VI', 'NRRELect')
cut_tree.add_edge('GD', 'NRRELect')
cut_tree.add_edge('NRRELect', 'SRFN')
nx.draw_planar(cut_tree, with_labels=True)
# Out:
# All biconnected components: [{'Portugal', 'Spain'}, {'Spain', 'France', 'Andorra'}, {'San Marino', 'Italy'}, {'Vatican City', 'Italy'}, {'Monaco', 'France'}, {'Germany', 'Denmark'}, {'Sweden', 'Russia', 'Finland', 'Norway'}, {'Netherlands', 'Russia', 'Romania', 'Estonia', 'Latvia', 'Montenegro', 'Austria', 'Armenia', 'Bulgaria', 'Albania', 'Croatia', 'Hungary', 'Liechtenstein', 'North Macedonia', 'Bosnia and Herzegovina', 'Greece', 'Slovakia', 'Slovenia', 'Kosovo', 'Luxembourg', 'France', 'Georgia', 'Lithuania', 'Moldova', 'Turkey', 'Serbia', 'Switzerland', 'Poland', 'Germany', 'Ukraine', 'Czech Republic', 'Belarus', 'Belgium', 'Italy'}]
# The block-cut tree:

# %%
print("All 2-edge-connected components:")
print(list(nx.biconnected_component_edges(graph)))
# Out:
# All 2-edge-connected components:
# ...

# %%
print("Для построения SPQR-Tree было использовано sagecell.sagemath.org")
print("   from sage.graphs.connectivity import spqr_tree")
print("   graph = Graph({'Armenia': ['Georgia', 'Turkey'], 'Georgia': ['Armenia', 'Russia', 'Turkey'], 'Turkey': ['Armenia', 'Bulgaria', 'Georgia', 'Greece'], 'Albania': ['Greece', 'Kosovo', 'North Macedonia', 'Montenegro'], 'Greece': ['Albania', 'Bulgaria', 'Turkey', 'North Macedonia'], 'Kosovo': ['Albania', 'Montenegro', 'North Macedonia', 'Serbia'], 'North Macedonia': ['Albania', 'Bulgaria', 'Greece', 'Kosovo', 'Serbia'], 'Montenegro': ['Albania', 'Bosnia and Herzegovina', 'Croatia', 'Kosovo', 'Serbia'], 'France': ['Belgium', 'Germany', 'Italy', 'Luxembourg', 'Switzerland'], 'Austria': ['Czech Republic', 'Germany', 'Hungary', 'Italy', 'Liechtenstein', 'Slovakia', 'Slovenia', 'Switzerland'], 'Czech Republic': ['Austria', 'Germany', 'Poland', 'Slovakia'], 'Germany': ['Austria', 'Belgium', 'Czech Republic', 'France', 'Luxembourg', 'Netherlands', 'Poland', 'Switzerland'], 'Hungary': ['Austria', 'Croatia', 'Romania', 'Serbia', 'Slovakia', 'Slovenia', 'Ukraine'], 'Italy': ['Austria', 'France', 'Slovenia', 'Switzerland'], 'Liechtenstein': ['Austria', 'Switzerland'], 'Slovakia': ['Austria', 'Czech Republic', 'Hungary', 'Poland', 'Ukraine'], 'Slovenia': ['Austria', 'Croatia', 'Hungary', 'Italy'], 'Switzerland': ['Austria', 'France', 'Germany', 'Italy', 'Liechtenstein'], 'Belarus': ['Latvia', 'Lithuania', 'Poland', 'Russia', 'Ukraine'], 'Latvia': ['Belarus', 'Estonia', 'Lithuania', 'Russia'], 'Lithuania': ['Belarus', 'Latvia', 'Poland', 'Russia'], 'Poland': ['Belarus', 'Czech Republic', 'Germany', 'Lithuania', 'Russia', 'Slovakia', 'Ukraine'], 'Russia': ['Belarus', 'Estonia', 'Georgia', 'Latvia', 'Lithuania', 'Poland', 'Ukraine'], 'Ukraine': ['Belarus', 'Hungary', 'Moldova', 'Poland', 'Romania', 'Russia', 'Slovakia'], 'Belgium': ['France', 'Germany', 'Luxembourg', 'Netherlands'], 'Luxembourg': ['Belgium', 'France', 'Germany'], 'Netherlands': ['Belgium', 'Germany'], 'Bosnia and Herzegovina': ['Croatia', 'Montenegro', 'Serbia'], 'Croatia': ['Bosnia and Herzegovina', 'Hungary', 'Montenegro', 'Serbia', 'Slovenia'], 'Serbia': ['Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Hungary', 'Kosovo', 'Montenegro', 'North Macedonia', 'Romania'], 'Bulgaria': ['Greece', 'North Macedonia', 'Romania', 'Serbia', 'Turkey'], 'Romania': ['Bulgaria', 'Hungary', 'Moldova', 'Serbia', 'Ukraine'], 'Estonia': ['Latvia', 'Russia'], 'Moldova': ['Romania', 'Ukraine']})")
print("   tree = spqr_tree(graph)")
print("   plot(tree)")
# Out:
# Для построения SPQR-Tree было использовано sagecell.sagemath.org
#    from sage.graphs.connectivity import spqr_tree
# ...
