# %%
import networkx as nx
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (18, 10)
countries=nx.Graph()
countries.add_edge('Armenia', 'Georgia', weight=170)
countries.add_edge('Armenia', 'Turkey', weight=992)
countries.add_edge('Albania', 'Greece', weight=500) 
countries.add_edge('Albania', 'Kosovo', weight=166)
countries.add_edge('Albania', 'North Macedonia', weight=152)
countries.add_edge('Albania', 'Montenegro', weight=132)
countries.add_edge('Andorra', 'France', weight=709)
countries.add_edge('Andorra', 'Spain', weight=493)
countries.add_edge('Austria', 'Czech Republic', weight=249)
countries.add_edge('Austria', 'Germany', weight=523)
countries.add_edge('Austria', 'Hungary', weight=214)
countries.add_edge('Austria', 'Italy', weight=765)
countries.add_edge('Austria', 'Liechtenstein', weight=526)
countries.add_edge('Austria', 'Slovakia', weight=55)
countries.add_edge('Austria', 'Slovenia', weight=278)
countries.add_edge('Austria', 'Switzerland', weight=683)
countries.add_edge('Belarus', 'Latvia', weight=404)
countries.add_edge('Belarus', 'Lithuania', weight=172)
countries.add_edge('Belarus', 'Poland', weight=475)
countries.add_edge('Belarus', 'Russia', weight=675)
countries.add_edge('Belarus', 'Ukraine', weight=433)
countries.add_edge('Belgium', 'France', weight=264)
countries.add_edge('Belgium', 'Germany', weight=649)
countries.add_edge('Belgium', 'Luxembourg', weight=187)
countries.add_edge('Belgium', 'Netherlands', weight=173)
countries.add_edge('Bosnia and Herzegovina', 'Croatia', weight=290)
countries.add_edge('Bosnia and Herzegovina', 'Montenegro', weight=171)
countries.add_edge('Bosnia and Herzegovina', 'Serbia', weight=194)
countries.add_edge('Bulgaria', 'Greece', weight=533)
countries.add_edge('Bulgaria', 'North Macedonia', weight=180)
countries.add_edge('Bulgaria', 'Romania', weight=288)
countries.add_edge('Bulgaria', 'Serbia', weight=325)
countries.add_edge('Bulgaria', 'Turkey', weight=852)
countries.add_edge('Croatia', 'Hungary', weight=299)
countries.add_edge('Croatia', 'Montenegro', weight=457)
countries.add_edge('Croatia', 'Serbia', weight=368)
countries.add_edge('Croatia', 'Slovenia', weight=116)
countries.add_edge('Czech Republic', 'Germany', weight=283)
countries.add_edge('Czech Republic', 'Poland', weight=517)
countries.add_edge('Czech Republic', 'Slovakia', weight=287)
countries.add_edge('Denmark', 'Germany', weight=356)
countries.add_edge('Estonia', 'Latvia', weight=277)
countries.add_edge('Estonia', 'Russia', weight=867)
countries.add_edge('Finland', 'Norway', weight=786)
countries.add_edge('Finland', 'Sweden', weight=395)
countries.add_edge('Finland', 'Russia', weight=892)
countries.add_edge('France', 'Germany', weight=876)
countries.add_edge('France', 'Italy', weight=1105)
countries.add_edge('France', 'Luxembourg', weight=287)
countries.add_edge('France', 'Monaco', weight=689)
countries.add_edge('France', 'Spain', weight=1053)
countries.add_edge('France', 'Switzerland', weight=435)
countries.add_edge('Germany', 'Luxembourg', weight=601)
countries.add_edge('Germany', 'Netherlands', weight=576)
countries.add_edge('Germany', 'Poland', weight=518)
countries.add_edge('Germany', 'Switzerland', weight=751)
countries.add_edge('Georgia', 'Russia', weight=1648)
countries.add_edge('Georgia', 'Turkey', weight=1026)
countries.add_edge('Greece', 'Turkey', weight=818)
countries.add_edge('Greece', 'North Macedonia', weight=487)
countries.add_edge('Hungary', 'Romania', weight=643)
countries.add_edge('Hungary', 'Serbia', weight=318)
countries.add_edge('Hungary', 'Slovakia', weight=161)
countries.add_edge('Hungary', 'Slovenia', weight=381)
countries.add_edge('Hungary', 'Ukraine', weight=899)
countries.add_edge('Ireland', 'United Kingdom', weight=465)
countries.add_edge('Italy', 'San Marino', weight=227)
countries.add_edge('Italy', 'Slovenia', weight=489)
countries.add_edge('Italy', 'Switzerland', weight=689)
countries.add_edge('Italy', 'Vatican City', weight=2)
countries.add_edge('Kosovo', 'Montenegro', weight=156)
countries.add_edge('Kosovo', 'North Macedonia', weight=77)
countries.add_edge('Kosovo', 'Serbia', weight=246)
countries.add_edge('Latvia', 'Lithuania', weight=263)
countries.add_edge('Latvia', 'Russia', weight=840)
countries.add_edge('Liechtenstein', 'Switzerland', weight=158)
countries.add_edge('Lithuania', 'Poland', weight=393)
countries.add_edge('Lithuania', 'Russia', weight=790)
countries.add_edge('Moldova', 'Romania', weight=357)
countries.add_edge('Moldova', 'Ukraine', weight=401)
countries.add_edge('Montenegro', 'Serbia', weight=281)
countries.add_edge('North Macedonia', 'Serbia', weight=323)
countries.add_edge('Norway', 'Sweden', weight=416)
countries.add_edge('Norway', 'Russia', weight=1643)
countries.add_edge('Poland', 'Russia', weight=1150)
countries.add_edge('Poland', 'Slovakia', weight=531)
countries.add_edge('Poland', 'Ukraine', weight=689)
countries.add_edge('Portugal', 'Spain', weight=503)
countries.add_edge('Romania', 'Serbia', weight=448)
countries.add_edge('Romania', 'Ukraine', weight=747)
countries.add_edge('Russia', 'Ukraine', weight=755)
countries.add_edge('Slovakia', 'Ukraine', weight=1004) 
countries.add_node('Cyprus')
countries.add_node('Iceland')
countries.add_node('Malta')

nx.draw_planar(countries, with_labels=True)

# %%
graph = countries.subgraph(max(nx.connected_components(countries)))
tree = nx.minimum_spanning_tree(graph)
nx.draw_planar(tree, with_labels = True)
